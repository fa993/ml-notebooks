# %%
from pylabel import importer, exporter, dataset, splitter
import pathlib
import pandas as pd

# %%
ds1 = importer.ImportVOC(path="data/indiancars/annotation/annotation", path_to_images="../../Vehicle_5_classes_sample", name="IndianCars")
print(ds1.df.head(5))
# Out:
# Importing VOC files...: 100%|███████████████| 745/745 [00:00<00:00, 5425.95it/s]
#                         img_folder                img_filename img_path  \
# id
# 0   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 1   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 2   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 3   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 4   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
#
#     img_id  img_width  img_height img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0        0       2448        3264      None             0           0.00
# 1        0       2448        3264      None             0           0.00
# 2        0       2448        3264      None             0         567.50
# 3        0       2448        3264      None             0        1818.86
# 4        0       2448        3264      None             0        1032.57
#
# ...

# %%
set(ds1.df['img_filename'])
# Out:
# {'20210427_05_35_43_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120.jpg',
#  '20210427_07_32_15_000_T4CaxysrQ7W21Wgl1wZWBCtdRjE3_F_3264_2448.jpg',
#  '20210427_07_33_01_000_T4CaxysrQ7W21Wgl1wZWBCtdRjE3_F_3264_2448.jpg',
#  '20210427_12_52_47_000_pgmtGnyv84hd7BiNoFr7ALIRzeZ2_F_4160_3120.jpg',
#  '20210427_19_51_59_000_xXhVe7Y5ShaVIcJB0hKzZOwzj0u2_F_3000_4000.jpg',
#  '20210427_22_52_25_000_Db2I2d17GLf53JzlQRSP28hD4Ml1_F_2592_1944.jpg',
#  '20210428_06_10_10_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120.jpg',
#  '20210428_12_03_31_000_iwOtXN9aQ0cLhGflMbWESATOmVt1_F_3000_4000.jpg',
#  '20210428_18_18_35_000_uA7x1XuBPngcHFRu7KambGvmgt62_F_5632_4224.jpg',
#  '20210429_11_49_33_000_fIZoRQmuZyVkc7oDgq1fjezTvCu1_F_4160_3120.jpg',
#  '20210429_14_22_24_000_M0qQbjq7mhasETXjCQGvnoZxK3a2_F_4160_3120.jpg',
#  '20210430_06_00_21_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120.jpg',
#  '20210430_13_41_55_000_KHbOZu7ST2RjrYR6xIgQjCrkntS2_F_4032_3024.jpg',
# ...

# %%
ds1.df.groupby(["cat_id", "cat_name"]).size()
# Out:
# cat_id  cat_name
# 0       two_wheelers     677
# 1       auto             357
# 2       car              364
# 3       tractor          183
# 4       bus              263
# 5       vehicle_truck    394
# 6       tempo            181
# 7       bicycle          116
# dtype: int64

# %%
len(ds1.df)
# Out:
# 2535

# %%
ds1.df.describe()
# Out:
#             img_id    img_width   img_height  ann_bbox_xmin  ann_bbox_ymin  \
# count  2535.000000  2535.000000  2535.000000    2535.000000    2535.000000
# mean    361.794872  2834.372387  3770.695069    1138.778458     961.530387
# std     215.365565   485.412288   603.825104     865.132420     596.120429
# min       0.000000   960.000000  1280.000000     -11.270000      -7.820000
# 25%     177.500000  2448.000000  3264.000000     425.365000     565.065000
# 50%     364.000000  3000.000000  4000.000000     971.770000     920.960000
# 75%     543.000000  3120.000000  4160.000000    1810.205000    1305.320000
# max     744.000000  5632.000000  5760.000000    4020.650000    3997.180000
#
#        ann_bbox_xmax  ann_bbox_ymax  ann_bbox_width  ann_bbox_height  \
# count    2535.000000    2535.000000     2535.000000      2535.000000
# mean     1749.828990    1561.770761      611.050533       600.240375
# std       871.741474     728.505719      660.255993       677.936402
# ...

# %%
ds1.df.head()
# Out:
#                         img_folder                img_filename img_path  \
# id
# 0   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 1   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 2   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 3   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
# 4   ../../Vehicle_5_classes_sample  Datacluster Auto (147).jpg      NaN
#
#     img_id  img_width  img_height img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0        0       2448        3264      None             0           0.00
# 1        0       2448        3264      None             0           0.00
# 2        0       2448        3264      None             0         567.50
# 3        0       2448        3264      None             0        1818.86
# 4        0       2448        3264      None             0        1032.57
#
#     ann_bbox_ymin  ...  ann_iscrowd  ann_keypoints  ann_pose  ann_truncated  \
# ...

# %%
splitter.Split(ds1).StratifiedGroupShuffleSplit(train_pct=0.8,test_pct=0.1,val_pct=0.1)

# %%
ds1.df.sample(5)
# Out:
#                           img_folder  \
# 1236  ../../Vehicle_5_classes_sample
# 1116  ../../Vehicle_5_classes_sample
# 23    ../../Vehicle_5_classes_sample
# 1863  ../../Vehicle_5_classes_sample
# 1559  ../../Vehicle_5_classes_sample
#
#                                            img_filename img_path  img_id  \
# 1236                        Datacluster Truck (179).jpg      NaN     534
# 1116  20210601_16_13_15_000_zHoQeOyp7mdLuEtqjxGYqdO2...      NaN     651
# 23                           Datacluster Truck (50).jpg      NaN     615
# 1863  20210513_16_24_30_000_1Zed4Oj2KLbPSd4mUWeNjmCU...      NaN     614
# 1559  20210526_09_29_44_000_Ih8kNBK4ntX3yX1SjxxlkYFn...      NaN     465
#
#       img_width  img_height img_depth ann_segmented  ann_bbox_xmin  \
# 1236       2448        3264      None             0        2059.51
# 1116       3120        4160      None             0        1011.27
# 23         3072        4096      None             0        1518.27
# ...

# %%
expr = exporter.Export(ds1)

# %%
expr.ExportToYoloV5(use_splits=True, copy_images=True)
# Out:
# Exporting YOLO files...: 100%|███████████████| 744/744 [00:03<00:00, 193.14it/s]
# ['training/dataset.yaml',
#  'training/labels/train/Datacluster Truck (149).txt',
#  'training/labels/train/20210522_18_01_12_000_wadXq0wFSqZtAe6KeW5TCRyhQ0R2_F_3120_4160.txt',
#  'training/labels/train/Datacluster Truck (34).txt',
#  'training/labels/train/20210602_09_22_07_000_bsfUf1M1E9bMsvY4ENiWwUWjDQp2_F_4160_3120.txt',
#  'training/labels/train/20210531_08_12_48_000_1sLQQulUcKc9QeR6Y5rRGuwPYU62_T_4160_3120.txt',
#  'training/labels/train/20210603_10_43_55_000_x0jb4abh7eQEpUg1dy2E5p8aCeV2_F_4160_3120.txt',
#  'training/labels/train/20210603_21_57_16_000_an8pifYgh8UUz4QuSiqCy2OqZ7u1_F_3264_2448.txt',
#  'training/labels/train/Datacluster Truck (50).txt',
#  'training/labels/train/Datacluster Auto (84).txt',
#  'training/labels/train/20210531_14_04_10_000_JPWRGJ4JOIS3Cw1UyLmfPHV3zfP2_F_3000_4000.txt',
#  'training/labels/train/Datacluster Auto (60).txt',
# ...
